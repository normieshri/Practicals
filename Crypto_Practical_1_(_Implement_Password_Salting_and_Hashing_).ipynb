# %%
# !pip install bcrypt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 698.9/698.9 kB 9.0 MB/s eta 0:00:00
# ...

# %%
import bcrypt

# %%
password = b'ShivSagar'

# %%
salt = bcrypt.gensalt()

# %%
hashed = bcrypt.hashpw(password, salt)

# %%
print("Salt : ", salt)
print("Hashed : ",hashed)
# Out:
# Salt :  b'$2b$12$Z9ZT1MIDGEV/wnZTSKOEj.'
# Hashed :  b'$2b$12$Z9ZT1MIDGEV/wnZTSKOEj.JC4XNeWUHmfkjs3hbqdVZx9UpEENW2O'
